# %%
print("Mutual Fund Recommendation System")
print("--------------------------------")
print("Dataset contains mutual fund information")
print("Performed Exploratory Data Analysis")
print("Built Content-Based Recommendation System")
print("Used CountVectorizer and Cosine Similarity")
print("Generated Top 5 Similar Mutual Fund Recommendations")
# Out:
# Mutual Fund Recommendation System
# --------------------------------
# Dataset contains mutual fund information
# Performed Exploratory Data Analysis
# Built Content-Based Recommendation System
# Used CountVectorizer and Cosine Similarity
# Generated Top 5 Similar Mutual Fund Recommendations
